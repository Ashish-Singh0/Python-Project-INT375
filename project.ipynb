# %% [markdown]
# **Importing CSV File**

# %%
df = pd.read_csv('CostReport.csv')

# %% [markdown]
# Rermoving unnecessary columns

# %%
drop = [
    'Cash on Hand and in Banks',
    'Temporary Investments',
    'Notes Receivable',
    'Prepaid Expenses',
    'Inventory',
    'Land',
    'Land Improvements',
    'Buildings',
    'Leasehold Improvements',
    'Minor Equipment Depreciable',
    'Health Information Technology Designated Assets',
    'Total Fixed Assets',
    'Investments',
    'Other Assets',
    'Accounts Payable',
    'Payroll Taxes Payable',
    'Notes and Loans Payable (Short Term)',
    'Deferred Income',
    'Unsecured Loans',
    'Total Other Assets',
    'Total Fund Balances',
    'DRG Amounts Before October 1',
    'DRG Amounts After October 1',
    'Outlier Payments For Discharges',
    'Medicaid Charges',
    'Stand-Alone CHIP Charges'
]

# %%
clean= df.drop(columns=drop, errors='ignore')

# %%
clean.to_csv('CostReport.csv', index=False)

# %%
df.head()
# Out:
#    rpt_rec_num  Provider CCN                         Hospital Name  \
# 0       717629        344028  STRATEGIC BEHAVIORAL CENTER - GARNER
# 1       717969        180078  PAUL B. HALL REGIONAL MEDICAL CENTER
# 2       719460        520210  MARSHFIELD MEDICAL CENTER-EAU CLAIRE
# 3       719475         63037         COBALT REHAB HOSP WESTMINSTER
# 4       721379        340123           AMERICAN HEALTHCARE SYSTEMS
#
#                         Street Address         City State Code    Zip Code  \
# 0                 3200 WATERFIELD ROAD       GARNER         NC  27529-7727
# 1  PAUL B. HALL REGIONAL MEDICAL CENTE  PAINTSVILLE         KY       41240
# 2                      2116 CRAIG ROAD   EAU CLAIRE         WI       54701
# 3                  6500 WEST 104TH AVE  WESTMINSTER         CO       80020
# 4        373 NORTH FAYETTEVILLE STREET     ASHEBORO         NC      27204-
#
#      County  Medicare CBSA Number Rural Versus Urban  ... Net Patient Revenue  \
# 0       NaN                   NaN                NaN  ...                 NaN
# 1   JOHNSON               99918.0                  R  ...           6182531.0
# 2       NaN               20740.0                  U  ...          61135683.0
# 3       NaN               79740.0                  U  ...            671606.0
# 4  RANDOLPH               24660.0                  U  ...          24492145.0
#
#    Less Total Operating Expense  Net Income from Service to Patients  \
# 0                           NaN                                  NaN
# 1                     5548061.0                             634470.0
# 2                    65395344.0                           -4259661.0
# 3                     2651952.0                           -1980346.0
# 4                    29740894.0                           -5248749.0
#
#   Total Other Income Total Income  Total Other Expenses  Net Income  \
# 0                NaN          NaN                   NaN         NaN
# 1          2151392.0    2785862.0                  15.0   2785847.0
# 2           845990.0   -3413671.0              151877.0  -3565548.0
# 3                NaN   -1980346.0                   NaN  -1980346.0
# 4         -6661015.0  -11909764.0                   NaN -11909764.0
#
#    Cost To Charge Ratio  Net Revenue from Medicaid  \
# 0                   NaN                        NaN
# 1              0.074617                  1114125.0
# 2              0.451411                 14333809.0
# 3                   NaN                        NaN
# 4              0.160752                  1724073.0
#
#    Net Revenue from Stand-Alone CHIP
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 91 columns]

# %%
df.shape
# Out:
# (6064, 91)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       rpt_rec_num  Provider CCN                         Hospital Name  \
# 0          717629        344028  STRATEGIC BEHAVIORAL CENTER - GARNER
# 1          717969        180078  PAUL B. HALL REGIONAL MEDICAL CENTER
# 2          719460        520210  MARSHFIELD MEDICAL CENTER-EAU CLAIRE
# 3          719475         63037         COBALT REHAB HOSP WESTMINSTER
# 4          721379        340123           AMERICAN HEALTHCARE SYSTEMS
# ...           ...           ...                                   ...
# 6059       776749        251325             COVINGTON COUNTY HOSPITAL
# 6060       776764        330273                PUTNAM HOSPITAL CENTER
# 6061       776821        453304              TEXAS CHILDRENS HOSPITAL
# 6062       776830        520096   WHEATON FRANCISCAN HEALTHCARE - ALL
# 6063       776832        520136  ASCENSION SE WISCONSIN HOSPITAL  INC
#
#                            Street Address         City State Code    Zip Code  \
# 0                    3200 WATERFIELD ROAD       GARNER         NC  27529-7727
# 1     PAUL B. HALL REGIONAL MEDICAL CENTE  PAINTSVILLE         KY       41240
# 2                         2116 CRAIG ROAD   EAU CLAIRE         WI       54701
# 3                     6500 WEST 104TH AVE  WESTMINSTER         CO       80020
# 4           373 NORTH FAYETTEVILLE STREET     ASHEBORO         NC      27204-
# ...                                   ...          ...        ...         ...
# 6059             803 GERALD MCRANEY DRIVE      COLLINS         MS       39428
# 6060                   670 STONELEIGH AVE       CARMEL         NY       10512
# 6061                          6621 FANNIN      HOUSTON         TX       77030
# 6062                   3801 SPRING STREET       RACINE         WI      53405-
# 6063            5000 WEST CHAMBERS STREET    MILWAUKEE         WI      53210-
#
#          County  Medicare CBSA Number Rural Versus Urban  ...  \
# 0           NaN                   NaN                NaN  ...
# 1       JOHNSON               99918.0                  R  ...
# 2           NaN               20740.0                  U  ...
# 3           NaN               79740.0                  U  ...
# 4      RANDOLPH               24660.0                  U  ...
# ...         ...                   ...                ...  ...
# 6059  COVINGTON               25620.0                  U  ...
# 6060     PUTNAM               35614.0                  U  ...
# 6061     HARRIS               26420.0                  U  ...
# 6062     RACINE               39540.0                  U  ...
# 6063  MILWAUKEE               33340.0                  U  ...
#
#      Net Patient Revenue  Less Total Operating Expense  \
# 0                    NaN                           NaN
# 1           6.182531e+06                  5.548061e+06
# 2           6.113568e+07                  6.539534e+07
# 3           6.716060e+05                  2.651952e+06
# 4           2.449214e+07                  2.974089e+07
# ...                  ...                           ...
# 6059        3.365041e+07                  4.248714e+07
# 6060        1.114786e+08                  1.462240e+08
# 6061        2.496681e+09                  3.242138e+09
# 6062        2.675222e+08                  3.147119e+08
# 6063        3.770394e+08                  3.740610e+08
#
#       Net Income from Service to Patients Total Other Income Total Income  \
# 0                                     NaN                NaN          NaN
# 1                                634470.0          2151392.0    2785862.0
# 2                              -4259661.0           845990.0   -3413671.0
# 3                              -1980346.0                NaN   -1980346.0
# 4                              -5248749.0         -6661015.0  -11909764.0
# ...                                   ...                ...          ...
# 6059                           -8836727.0          9720711.0     883984.0
# 6060                          -34745401.0          8546504.0  -26198897.0
# 6061                         -745457447.0        563597452.0 -181859995.0
# 6062                          -47189765.0         46937294.0    -252471.0
# 6063                            2978391.0          5402430.0    8380821.0
#
#       Total Other Expenses   Net Income  Cost To Charge Ratio  \
# 0                      NaN          NaN                   NaN
# 1                     15.0    2785847.0              0.074617
# 2                 151877.0   -3565548.0              0.451411
# 3                      NaN   -1980346.0                   NaN
# 4                      NaN  -11909764.0              0.160752
# ...                    ...          ...                   ...
# 6059                   NaN     883984.0              0.570367
# 6060            12215632.0  -38414529.0              0.383837
# 6061            -2383805.0 -179476190.0                   NaN
# 6062              127905.0    -380376.0              0.287414
# 6063              778536.0    7602285.0              0.270474
#
#       Net Revenue from Medicaid  Net Revenue from Stand-Alone CHIP
# 0                           NaN                                NaN
# 1                     1114125.0                                NaN
# 2                    14333809.0                                NaN
# 3                           NaN                                NaN
# 4                     1724073.0                                NaN
# ...                         ...                                ...
# 6059                  1258502.0                                NaN
# 6060                  7927612.0                                NaN
# 6061                        NaN                                NaN
# 6062                 55447458.0                                NaN
# 6063                 75932456.0                                NaN
#
# [6064 rows x 91 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6064 entries, 0 to 6063
# Data columns (total 91 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   rpt_rec_num                                                              6064 non-null   int64
#  1   Provider CCN                                                             6064 non-null   int64
#  2   Hospital Name                                                            6064 non-null   object
#  3   Street Address                                                           6061 non-null   object
#  4   City                                                                     6064 non-null   object
#  5   State Code                                                               6064 non-null   object
#  6   Zip Code                                                                 6064 non-null   object
#  7   County                                                                   5500 non-null   object
#  8   Medicare CBSA Number                                                     5981 non-null   float64
#  9   Rural Versus Urban                                                       5981 non-null   object
#  10  CCN Facility Type                                                        6064 non-null   object
#  11  Provider Type                                                            6064 non-null   int64
#  12  Type of Control                                                          6064 non-null   int64
#  13  Fiscal Year Begin Date                                                   6064 non-null   object
#  14  Fiscal Year End Date                                                     6064 non-null   object
#  15  FTE - Employees on Payroll                                               5946 non-null   float64
#  16  Number of Interns and Residents (FTE)                                    1499 non-null   float64
#  17  Total Days Title V                                                       134 non-null    float64
#  18  Total Days Title XVIII                                                   5913 non-null   float64
#  19  Total Days Title XIX                                                     5051 non-null   float64
#  20  Total Days (V + XVIII + XIX + Unknown)                                   5963 non-null   float64
#  21  Number of Beds                                                           5970 non-null   float64
#  22  Total Bed Days Available                                                 5970 non-null   float64
#  23  Total Discharges Title V                                                 126 non-null    float64
#  24  Total Discharges Title XVIII                                             5922 non-null   float64
#  25  Total Discharges Title XIX                                               4981 non-null   float64
#  26  Total Discharges (V + XVIII + XIX + Unknown)                             5962 non-null   float64
#  27  Number of Beds + Total for all Subproviders                              5975 non-null   float64
#  28  Hospital Total Days Title V For Adults & Peds                            124 non-null    float64
#  29  Hospital Total Days Title XVIII For Adults & Peds                        5898 non-null   float64
#  30  Hospital Total Days Title XIX For Adults & Peds                          4988 non-null   float64
#  31  Hospital Total Days (V + XVIII + XIX + Unknown) For Adults & Peds        5960 non-null   float64
#  32  Hospital Number of Beds For Adults & Peds                                5966 non-null   float64
#  33  Hospital Total Bed Days Available For Adults & Peds                      5967 non-null   float64
#  34  Hospital Total Discharges Title V For Adults & Peds                      126 non-null    float64
#  35  Hospital Total Discharges Title XVIII For Adults & Peds                  5922 non-null   float64
#  36  Hospital Total Discharges Title XIX For Adults & Peds                    4981 non-null   float64
#  37  Hospital Total Discharges (V + XVIII + XIX + Unknown) For Adults & Peds  5962 non-null   float64
#  38  Cost of Charity Care                                                     4244 non-null   float64
#  39  Total Bad Debt Expense                                                   4456 non-null   float64
#  40  Cost of Uncompensated Care                                               4515 non-null   float64
#  41  Total Unreimbursed and Uncompensated Care                                4536 non-null   float64
#  42  Total Salaries From Worksheet A                                          5977 non-null   float64
#  43  Overhead Non-Salary Costs                                                5981 non-null   float64
#  44  Depreciation Cost                                                        5915 non-null   float64
#  45  Total Costs                                                              5981 non-null   float64
#  46  Inpatient Total Charges                                                  5975 non-null   float64
#  47  Outpatient Total Charges                                                 5449 non-null   float64
#  48  Combined Outpatient + Inpatient Total Charges                            5981 non-null   float64
#  49  Wage-Related Costs (Core)                                                3600 non-null   float64
#  50  Wage-Related Costs (RHC/FQHC)                                            383 non-null    float64
#  51  Total Salaries (adjusted)                                                3746 non-null   float64
#  52  Contract Labor: Direct Patient Care                                      3188 non-null   float64
#  53  Wage Related Costs for Part - A Teaching Physicians                      406 non-null    float64
#  54  Wage Related Costs for Interns and Residents                             813 non-null    float64
#  55  Accounts Receivable                                                      5688 non-null   float64
#  56  Less: Allowances for Uncollectible Notes and Accounts Receivable         4101 non-null   float64
#  57  Other Current Assets                                                     2459 non-null   float64
#  58  Total Current Assets                                                     5744 non-null   float64
#  59  Fixed Equipment                                                          3399 non-null   float64
#  60  Major Movable Equipment                                                  5199 non-null   float64
#  61  Total Assets                                                             5762 non-null   float64
#  62  Salaries, Wages, and Fees Payable                                        5167 non-null   float64
#  63  Other Current Liabilities                                                5036 non-null   float64
#  64  Total Current Liabilities                                                5730 non-null   float64
#  65  Mortgage Payable                                                         746 non-null    float64
#  66  Notes Payable                                                            2396 non-null   float64
#  67  Other Long Term Liabilities                                              4057 non-null   float64
#  68  Total Long Term Liabilities                                              5092 non-null   float64
#  69  Total Liabilities                                                        5732 non-null   float64
#  70  General Fund Balance                                                     5750 non-null   float64
#  71  Total Liabilities and Fund Balances                                      5759 non-null   float64
#  72  DRG Amounts Other Than Outlier Payments                                  0 non-null      float64
#  73  Disproportionate Share Adjustment                                        2729 non-null   float64
#  74  Allowable DSH Percentage                                                 2777 non-null   float64
#  75  Managed Care Simulated Payments                                          1987 non-null   float64
#  76  Total IME Payment                                                        1278 non-null   float64
#  77  Inpatient Revenue                                                        5818 non-null   float64
#  78  Outpatient Revenue                                                       5284 non-null   float64
#  79  Total Patient Revenue                                                    5821 non-null   float64
#  80  Less Contractual Allowance and Discounts on Patients' Accounts           5740 non-null   float64
#  81  Net Patient Revenue                                                      5823 non-null   float64
#  82  Less Total Operating Expense                                             5979 non-null   float64
#  83  Net Income from Service to Patients                                      5979 non-null   float64
#  84  Total Other Income                                                       5751 non-null   float64
#  85  Total Income                                                             5973 non-null   float64
#  86  Total Other Expenses                                                     1778 non-null   float64
#  87  Net Income                                                               5974 non-null   float64
#  88  Cost To Charge Ratio                                                     4600 non-null   float64
#  89  Net Revenue from Medicaid                                                4385 non-null   float64
#  90  Net Revenue from Stand-Alone CHIP                                        986 non-null    float64
# dtypes: float64(77), int64(4), object(10)
# memory usage: 4.2+ MB

# %%
df.isnull().sum()
# Out:
# rpt_rec_num                             0
# Provider CCN                            0
# Hospital Name                           0
# Street Address                          3
# City                                    0
#                                      ...
# Total Other Expenses                 4286
# Net Income                             90
# Cost To Charge Ratio                 1464
# Net Revenue from Medicaid            1679
# Net Revenue from Stand-Alone CHIP    5078
# Length: 91, dtype: int64

# %% [markdown]
# **EDA AND VISUALISATION**

# %% [markdown]
# Count of records per state

# %%
state_counts = df['State Code'].value_counts().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=state_counts.index, y=state_counts.values)
plt.title('Distribution of Records by State')
plt.xlabel('State')
plt.ylabel('Number of Records')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Net Patient Revenue by Year

# %%
print(df.columns[df.columns.str.contains("date", case=False)])
# Out:
# Index(['Fiscal Year Begin Date', 'Fiscal Year End Date'], dtype='object')

# %%
df['Report Date'] = pd.to_datetime(df['Fiscal Year Begin Date'])
df['Year'] = df['Report Date'].dt.year
df.groupby('Year')['Net Patient Revenue'].sum().plot(kind='bar')
plt.title('Net Patient Revenue by Year')
plt.show()

# %% [markdown]
# Outliers of Net Patient Revevue , Net Income and Medicare CBSA Number

# %%
sns.set(style="whitegrid")

cols_to_plot = ['Net Patient Revenue', 'Net Income', 'Medicare CBSA Number']

fig, axes = plt.subplots(1, len(cols_to_plot), figsize=(18, 6), constrained_layout=True)

for i, col in enumerate(cols_to_plot):
    if col in df.columns:
        sns.boxplot(data=df, x=col, ax=axes[i], color='skyblue', width=0.4, fliersize=4)
        axes[i].set_title(f"{col}", fontsize=14, fontweight='bold')
        axes[i].set_xlabel("")
        axes[i].tick_params(axis='x', rotation=30)

plt.suptitle("Outlier Detection Using Boxplots", fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# Heatmap correlation

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12, 10))
sns.heatmap(corr, cmap='coolwarm', annot=False, linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Average Net Income by Fiscal Year

# %%
df['Fiscal Year End Date'] = pd.to_datetime(df['Fiscal Year End Date'], errors='coerce')


if 'Net Income' in df.columns:
    df['Net Income'] = pd.to_numeric(df['Net Income'], errors='coerce')
    trend_df = df.groupby(df['Fiscal Year End Date'].dt.year)['Net Income'].mean().dropna()

    plt.figure(figsize=(10, 5))
    sns.lineplot(x=trend_df.index, y=trend_df.values, marker="o")
    plt.title("Average Net Income by Fiscal Year")
    plt.xlabel("Year")
    plt.ylabel("Average Net Income")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    trend_df = None

trend_df
# Out:
# Fiscal Year End Date
# 2021   -3.372744e+06
# 2022    1.207735e+06
# 2023    1.521463e+07
# Name: Net Income, dtype: float64

# %% [markdown]
# Net Patient Revenue vs Net Income(Scatter plot)

# %%
# Drop rows with missing values
df_scatter = df[['Net Patient Revenue', 'Net Income']].dropna()

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_scatter, x='Net Patient Revenue', y='Net Income', alpha=0.6)
plt.title('Scatter Plot: Net Patient Revenue vs Net Income')
plt.xlabel('Net Patient Revenue')
plt.ylabel('Net Income')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Record Distribution by State (Top 15)

# %%
if 'State Code' in df.columns:
    plt.figure(figsize=(12, 6))
    state_counts = df['State Code'].value_counts().sort_values(ascending=False).head(15)
    sns.barplot(x=state_counts.index, y=state_counts.values, palette="viridis")
    plt.title("Top 15 States by Number of Records")
    plt.xlabel("State")
    plt.ylabel("Record Count")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_17948\2965039454.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=state_counts.index, y=state_counts.values, palette="viridis")

# %% [markdown]
# Pie Chart of Records by State Code of top 10

# %%
if 'State Code' in df.columns:
    provider_counts = df['State Code'].value_counts().head(10)

    plt.figure(figsize=(8, 8))
    plt.pie(
        provider_counts.values,
        labels=provider_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        wedgeprops={'edgecolor': 'black'}
    )
    plt.title('Top 10 Provider Types by Record Count')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

# %% [markdown]
#  Donut Chart by 'type of control' of top 10

# %%
col = 'Type of Control'

if col in df.columns:
    top_counts = df[col].value_counts().head(10)

    plt.figure(figsize=(8, 8))
    wedges, texts, autotexts = plt.pie(
        top_counts.values,
        labels=None, 
        autopct='%1.1f%%',
        startangle=140,
        wedgeprops={'width': 0.4, 'edgecolor': 'white'} 
    )
    plt.legend(
        wedges,
        top_counts.index,
        title=col,
        loc='center left',
        bbox_to_anchor=(1, 0.5)
    )

    plt.title(f'Top 10 {col} Distribution (Donut Chart)')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Prediction for 2024 & 2025**

# %%
df['Fiscal Year End Date'] = pd.to_datetime(df['Fiscal Year End Date'], errors='coerce')
df['Fiscal Year'] = df['Fiscal Year End Date'].dt.year

revenue_by_year = (
    df.groupby('Fiscal Year')['Net Patient Revenue']
    .sum()
    .dropna()
    .sort_index()
)

revenue_by_year
years = revenue_by_year.index.values.reshape(-1, 1)
revenues = revenue_by_year.values

# Train linear regression model
model = LinearRegression()
model.fit(years, revenues)

future_years = np.array([[2024], [2025]])
future_predictions = model.predict(future_years)

all_years = np.append(years.flatten(), future_years.flatten())
all_revenues = np.append(revenues, future_predictions)


plt.figure(figsize=(10, 6))
plt.plot(all_years, all_revenues / 1e9, marker='o', linestyle='-', color='blue', label='Net Patient Revenue (Billion USD)')


for x, y in zip(all_years, all_revenues):
    plt.text(x, y / 1e9 + 10, f"${y/1e9:.1f}B", ha='center', fontsize=9)


plt.plot(future_years, future_predictions / 1e9, 'ro', label='Predicted')


plt.title("Net Patient Revenue by Fiscal Year (with 2024 & 2025 Prediction)", fontsize=14)
plt.xlabel("Fiscal Year")
plt.ylabel("Revenue (in Billion USD)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()

plt.show()
